# %%
# import the libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing the datasets

# %%
client_data = pd.read_csv('client_data.csv')
price_data = pd.read_csv('price_data.csv')

# %%
client_data.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
client_data.tail(5)
# Out:
#                                      id                     channel_sales  \
# 14601  18463073fb097fc0ac5d3e040f356987  foosdfpfkusacimwkcsosbicdxkicaua
# 14602  d0a6f71671571ed83b2645d23af6de00  foosdfpfkusacimwkcsosbicdxkicaua
# 14603  10e6828ddd62cbcf687cb74928c4c2d2  foosdfpfkusacimwkcsosbicdxkicaua
# 14604  1cf20fd6206d7678d5bcafd28c53b4db  foosdfpfkusacimwkcsosbicdxkicaua
# 14605  563dde550fd624d7352f3de77c0cdfcd                           MISSING
#
#        cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 14601     32270         47940                0  2012-05-24  2016-05-08
# 14602      7223             0              181  2012-08-27  2016-08-27
# 14603      1844             0              179  2012-02-08  2016-02-07
# 14604       131             0                0  2012-08-30  2016-08-30
# 14605      8730             0                0  2009-12-18  2016-12-17
#
#       date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
price_data.head(5)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
price_data.tail(5)
# Out:
#                                       id  price_date  price_off_peak_var  \
# 192997  16f51cdc2baa19af0b940ee1b3dd17d5  2015-08-01            0.119916
# 192998  16f51cdc2baa19af0b940ee1b3dd17d5  2015-09-01            0.119916
# 192999  16f51cdc2baa19af0b940ee1b3dd17d5  2015-10-01            0.119916
# 193000  16f51cdc2baa19af0b940ee1b3dd17d5  2015-11-01            0.119916
# 193001  16f51cdc2baa19af0b940ee1b3dd17d5  2015-12-01            0.119916
#
#         price_peak_var  price_mid_peak_var  price_off_peak_fix  \
# 192997        0.102232            0.076257           40.728885
# 192998        0.102232            0.076257           40.728885
# 192999        0.102232            0.076257           40.728885
# 193000        0.102232            0.076257           40.728885
# 193001        0.102232            0.076257           40.728885
#
#         price_peak_fix  price_mid_peak_fix
# 192997        24.43733           16.291555
# 192998        24.43733           16.291555
# ...

# %%
# check data types

# %%
client_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %%
# Data Statistics

# %%
client_data.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
price_data.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %%
# merge the datasets using 'id'

# %%
merged_data = pd.merge(client_data,price_data, on='id')

# %%
merged_data.sample(3)
# Out:
#                                       id                     channel_sales  \
# 172698  23a0c279199ec4e17eb2b7966b216e84                           MISSING
# 11745   cfbbd632d967bb6d6ebdf77c9a7613b9  lmkebamcaaclubfxadlmueccxoimlema
# 67954   3d5e902bea9a67154daa0b5dbe25f113  foosdfpfkusacimwkcsosbicdxkicaua
#
#         cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 172698      1613             0                0  2009-12-11  2016-11-22
# 11745      52777             0             4444  2010-07-21  2016-07-21
# 67954      16830             0             2715  2012-11-13  2017-01-23
#
#        date_modif_prod date_renewal  forecast_cons_12m  ...  \
# 172698      2014-11-17   2015-11-23             231.97  ...
# 11745       2010-07-21   2015-07-31            2290.46  ...
# 67954       2014-01-20   2016-01-24            2230.08  ...
#
#                                origin_up  pow_max  churn  price_date  \
# ...

# %%
# Convert date into datetime from object type

# %%
merged_data['date_activ'] = pd.to_datetime(merged_data['date_activ'])
merged_data['date_end'] = pd.to_datetime(merged_data['date_activ'])
merged_data['date_modif_prod'] = pd.to_datetime(merged_data['date_activ'])
merged_data['date_renewal'] = pd.to_datetime(merged_data['date_activ'])
merged_data['price_date'] = pd.to_datetime(merged_data['date_activ'])

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175149 entries, 0 to 175148
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              175149 non-null  object
#  1   channel_sales                   175149 non-null  object
#  2   cons_12m                        175149 non-null  int64
#  3   cons_gas_12m                    175149 non-null  int64
#  4   cons_last_month                 175149 non-null  int64
#  5   date_activ                      175149 non-null  datetime64[ns]
#  6   date_end                        175149 non-null  datetime64[ns]
#  7   date_modif_prod                 175149 non-null  datetime64[ns]
#  8   date_renewal                    175149 non-null  datetime64[ns]
#  9   forecast_cons_12m               175149 non-null  float64
#  10  forecast_cons_year              175149 non-null  int64
# ...

# %%
# Data Visualization

# %%
# 1. Power and Gas Consumption in the past 12 months

# %%
merged_data.sort_values(by='price_date', inplace=True)
power_consumption = merged_data[['price_date', 'cons_12m']]
gas_consumption = merged_data[['price_date', 'cons_gas_12m']]

plt.figure(figsize=(10, 6))
plt.plot(power_consumption['price_date'], power_consumption['cons_12m'], label='Power Consumption', color='blue')
plt.plot(gas_consumption['price_date'], gas_consumption['cons_gas_12m'], label='Gas Consumption', color='orange')

plt.xlabel('Date')
plt.ylabel('Consumption')
plt.title('Power and Gas Consumption in the Last 12 Months')
plt.legend()

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# 2. Sales Channel

# %%
# count the occurences of sales channels
sales_channel_count = client_data['channel_sales'].value_counts()
plt.figure(figsize=(8,6))
sns.barplot(x=sales_channel_count.index, y=sales_channel_count.values, palette='viridis')

plt.xlabel('Sales Channel')
plt.ylabel('Number of clients')
plt.title('Distribution of sales channels')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 3. Distribution of Gas Clients

# %%
# Count the occurrences of 'has_gas' values
gas_client_counts = client_data['has_gas'].value_counts()
plt.figure(figsize=(6, 6))
sns.barplot(x=gas_client_counts.index, y=gas_client_counts.values, palette='magma')

#labels and title
plt.xlabel('Has Gas Client')
plt.ylabel('Number of Clients')
plt.title('Distribution of Gas Clients')
plt.tight_layout()
plt.show()

# %%
# 4. Churn Rate

# %%
churn_counts = merged_data['churn'].value_counts()
plt.figure(figsize=(6, 6))  
plt.bar(['Churned', 'Retained'], churn_counts.values, color=['red', 'green'])
plt.xlabel('Churn Status')
plt.ylabel('Number of Customers')
plt.title('Churn Visualization')
for i, count in enumerate(churn_counts):
    plt.text(i, count, str(count), ha='center', va='bottom', fontsize=12, fontweight='bold')
    plt.tight_layout() 
plt.show()

# %%
# 5. Forcasted Vs. Actual electricity cunsumption in last 12 months

# %%
plt.figure(figsize=(12, 6)) 
plt.plot(merged_data['date_activ'], merged_data['cons_12m'], marker='o', color='b', label='Actual Consumption')
plt.plot(merged_data['date_activ'], merged_data['forecast_cons_12m'], marker='o', color='r', label='Forecasted Consumption')
plt.xlabel('Date')
plt.ylabel('Electricity Consumption')
plt.title('Actual vs. Forecasted Electricity Consumption ')
plt.legend()
plt.grid(True) 
plt.tight_layout() 
plt.xticks(rotation=45) 
plt.show()

# %%
# 6. Margin

# %%
plt.figure(figsize=(8, 6))
plt.bar(['Gross Margin', 'Net Margin'],
        [merged_data['margin_gross_pow_ele'].mean(), merged_data['margin_net_pow_ele'].mean()],
        color=['blue', 'green'])
plt.xlabel('Margin Type')
plt.ylabel('Average Margin')
plt.title('Comparison of Gross and Net Margins')
plt.tight_layout()  
plt.show()

# %%
# 7. Distribution of margin to identify outliers

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=merged_data[['margin_gross_pow_ele', 'margin_net_pow_ele']], palette='pastel')
plt.ylabel('Margin')
plt.title('Distribution of Gross and Net Margins')
plt.show()

# %%
# 8. Relationship between Margin and Electricity Consumption

# %%
plt.figure(figsize=(10, 6))
plt.scatter(merged_data['cons_12m'], merged_data['margin_gross_pow_ele'], color='blue', label='Gross Margin')
plt.scatter(merged_data['cons_12m'], merged_data['margin_net_pow_ele'], color='green', label='Net Margin')
plt.xlabel('Electricity Consumption')
plt.ylabel('Margin')
plt.title('Margins vs. Electricity Consumption')
plt.legend()
plt.show()
